# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Ступенчатый (**step**) график

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.arange(0, 10)
y = np.arange(0, 5, 0.5)
ax.step(x, y)
ax.grid()

plt.show()

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.arange(0, 10)
y = np.arange(0, 5, 0.5)
ax.step(x, y, '-go')
ax.grid()

plt.show()

# %% [markdown]
# ## Инверсия графика

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.arange(0, 10)
y = np.arange(0, 5, 0.5)
ax.step(x, y, '-go', where='post')
ax.grid()

plt.show()

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.arange(0, 10)
y = np.arange(0, 5, 0.5)
ax.step(x, y, '-go', where='mid')
ax.grid()

plt.show()

# %% [markdown]
# ## Размещаем на оси сразу несколько графиков

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.arange(0, 10)
y = np.arange(0, 5, 0.5)
z = np.cos(x)
ax.step(x, y, '-go', x, z, '--bs', where='post')
ax.grid()

plt.show()

# %% [markdown]
# # Стековый график

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.arange(-2, 2, 0.1)
y1 = np.array([-y**2 for y in x]) + 8
y2 = np.array([-y**2 for y in x]) + 8
y3 = np.array([-y**2 for y in x]) + 8
ax.stackplot(x, y1, y2, y3)

ax.grid()

plt.show()

# %% [markdown]
# # **Stem**-график

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi, np.pi, 0.3)
ax.stem(x, np.cos(x))

ax.grid()

plt.show()

# %% [markdown]
# ## Изменяем положение линии бозового уровня при помощи параметра **bottom=**

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi, np.pi, 0.3)
ax.stem(x, np.cos(x), bottom=0.5)

ax.grid()

plt.show()

# %% [markdown]
# ## Измерим тип и цвет линий:

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi, np.pi, 0.3)
ax.stem(x, np.cos(x), '--g', bottom=0.5)

ax.grid()

plt.show()

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi, np.pi, 0.3)
ax.stem(x, np.cos(x), linefmt=('grey','--'), markerfmt=('blue','^'), basefmt=('red', ':'), bottom=0.5)

ax.grid()

plt.show()

# %% [markdown]
# # Точечный график

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.random.normal(0, 2, 500)
y = np.random.normal(0, 2, 500)

ax.scatter(x, y)

ax.grid()

plt.show()

# %% [markdown]
# Измерим параметры точек:

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.random.normal(0, 2, 500)
y = np.random.normal(0, 2, 500)

ax.scatter(x, y, s=50, c='w', linewidths=1, marker='s', edgecolors='r')

ax.grid()

plt.show()
